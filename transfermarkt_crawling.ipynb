# %% [markdown]
# ## Library
#
# - Requests
#   - https://requests.readthedocs.io/en/master/
#   - html 읽어오기
#   - 정적 웹페이지
#   - 빠름
# - Selenium
#   - 웹페이지 자동화
#   - 동적 웹페이지 (스크롤, 로그인, ..)
#   - 느림
# - BeautifulSoup
#   - https://www.crummy.com/software/BeautifulSoup/bs4/doc/#quick-start
#   - 원하는 데이터 가져옴 (스크래핑)

# %% [markdown]
# ## Crawling

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {'User-Agent': '-'}

player_list = []

for i in range(1, 21):
    url = f"https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?ajax=yw1&page={i}"

    r = requests.get(url, headers=headers)
    r.status_code

    soup = BeautifulSoup(r.text, 'html.parser')

    player_info = soup.find_all('tr', class_=['odd', 'even'])

    for info in player_info:
        player = info.find_all('td')

        number = player[0].text
        name = player[3].text
        position = player[4].text
        age = player[5].text
        nation= player[6].img['alt']
        club = player[7].img['alt']
        value = player[8].text.strip()

        player_list.append([number, name, position, age, nation, club, value])

    time.sleep(1)

# %%
df = pd.DataFrame(player_list, columns=['number', 'name', 'position', 'age', 'nation', 'club', 'value'])
df
# Out:
#     number                   name            position age       nation  \
# 0        1        Jude Bellingham  Attacking Midfield  20      England
# 1        2         Erling Haaland      Centre-Forward  23       Norway
# 2        3          Kylian Mbappé      Centre-Forward  25       France
# 3        4        Vinicius Junior         Left Winger  23       Brazil
# 4        5            Bukayo Saka        Right Winger  22      England
# ..     ...                    ...                 ...  ..          ...
# 495    496               Noa Lang         Left Winger  24  Netherlands
# 496    497           Sander Berge  Defensive Midfield  26       Norway
# 497    498  Christoph Baumgartner  Attacking Midfield  24      Austria
# 498    499    Sebastian Szymanski  Attacking Midfield  24       Poland
# 499    500          Marco Asensio        Right Winger  28        Spain
#
#                     club     value
# 0            Real Madrid  €180.00m
# 1        Manchester City  €180.00m
# 2    Paris Saint-Germain  €180.00m
# 3            Real Madrid  €150.00m
# 4             Arsenal FC  €130.00m
# ..                   ...       ...
# 495        PSV Eindhoven   €20.00m
# 496           Burnley FC   €20.00m
# 497           RB Leipzig   €20.00m
# 498           Fenerbahce   €20.00m
# 499  Paris Saint-Germain   €20.00m
#
# [500 rows x 7 columns]

# %% [markdown]
# ## 타입 변환, 'value' 문자 제거

# %%
import numpy as np

# %%
df['number'] = df['number'].astype(int)
df['age'] = df['age'].astype(int)

# %%
df['value'] = df['value'].str.replace('€','')
df['value'] = df['value'].str.replace('m','').astype('float')

# %%
df.set_index('number', inplace=True)

# %% [markdown]
# ## 파일저장

# %%
df.to_csv('transfermarkt_crawling.csv, index=True')
